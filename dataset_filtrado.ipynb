# %%
import pandas as pd

df_spotify = pd.read_excel('dataset_filtrado.xlsx')

# %%
df_spotify.shape
# Out:
# (401526, 29)

# %%
df_spotify.head()
# Out:
#     Column1                                        title  rank       date  \
# 0  18244039                                            炎     7 2020-12-03
# 1  18387532  La mano de Dios (Homenaje a Diego Maradona)     4 2020-12-01
# 2  18387533                                   Travesuras     5 2020-12-01
# 3  18387534                           Dancing in My Room     6 2020-12-01
# 4  18387535                                 Hecha Pa' Mi     7 2020-12-01
#
#                                      artist  \
# 0                                      LiSA
# 1                                   Rodrigo
# 2  Flow La Movie, Nio Garcia, Casper Magico
# 3                                  347aidan
# 4                                      Boza
#
#                                                  url     region    chart  \
# 0  https://open.spotify.com/track/0cSkn2l67csUljE...  Singapore  viral50
# 1  https://open.spotify.com/track/5s8onl5Lw5q1Aij...  Argentina  viral50
# ...

# %%
#Limpieza de valores NaN
df_spotify_no_na = df_spotify.copy()
df_spotify_no_na["streams"] = df_spotify["streams"].fillna(0)
df_spotify_no_na.describe()
# Out:
#             Column1           rank                           date   streams  \
# count  4.015260e+05  401526.000000                         401526  401526.0
# mean   1.926790e+07      25.505135  2020-05-06 21:55:55.018603776       0.0
# min    1.824404e+07       1.000000            2020-01-01 00:00:00       0.0
# 25%    1.889697e+07      13.000000            2020-01-30 00:00:00       0.0
# 50%    1.931897e+07      26.000000            2020-02-29 00:00:00       0.0
# 75%    1.965371e+07      38.000000            2020-12-02 00:00:00       0.0
# max    1.998130e+07      51.000000            2020-12-31 00:00:00       0.0
# std    4.369993e+05      14.434171                            NaN       0.0
#
#           popularity   duration_ms                   release_date  \
# count  401526.000000  4.015260e+05                         401352
# mean      427.522327  2.002184e+06  2018-11-30 17:23:32.186808320
# min         0.000000  0.000000e+00            1900-01-01 00:00:00
# ...

# %%
#Grafico de dispersion entre streams y positividad
import matplotlib.pyplot as plt

popularity = df_spotify_no_na["popularity"]
positividad = df_spotify_no_na["af_valence"]

plt.scatter(popularity, bailabilidad)

plt.xlabel('Popularidad')
plt.ylabel('positividad')
plt.title('Popularidad de una cancion vs su positividad')

plt.show()
